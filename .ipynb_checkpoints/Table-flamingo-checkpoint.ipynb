# %%
import astropy
import numpy as np
import pandas as pd

# %% [markdown]
# ## Section1 : Parameters of the simulation: cosmology, box size, geometry, origin of lightcone etc

# %%
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u

## Box Size (in Mpc)
BoxLength = 2800. 

#ORIGIN OF THE LIGHTCONE
origin = [BoxLength/4,BoxLength/4,BoxLength/4]


## Fullsky: True or False
FullSky = True

#DIRECTION VECTOR OF THE LIGHTCONE
if not FullSky:
    ra = np.radians(31) 
    piby2_minus_dec  = np.radians(80)  ## 80 is the theta in spherical coordinates
    direction_vector=[np.cos(ra)*np.sin(piby2_minus_dec),np.sin(ra)*np.sin(piby2_minus_dec),np.cos(piby2_minus_dec)]

#COSMOLOGY
om = 0.304611 ### cosmology of flaminggo D3A
ol = 0.693922
H = 68.1 * u.km / u.s / u.Mpc
h = H.value/100

m_nu = [0.0,0.02,0.04] *u.eV
cosmo = FlatLambdaCDM(H0=H, Om0=om, Ob0=0.049, Tcmb0=2.725)
redshift_file='/nfs/pic.es/user/s/sramakri/Flamingo/flamingo_params.txt'
df=pd.read_csv(redshift_file,usecols=[0,2],names=['snap','z'],skiprows=1,delimiter=' ')
redshift = {str(snap): [z] for snap, z in zip(df.sort_values('snap', ascending=False)['snap'], df.sort_values('snap', ascending=False)['z'])}

#redshift = {"144":[0],"143":[0.009522],'142':[0.019134],'141':[0.028838]}

for i, label in enumerate(redshift.keys()):
    redshift[label].append(cosmo.comoving_distance(redshift[label][0]).value)
comov_dist = np.zeros([len(redshift)])
redshift_array = np.zeros([len(redshift)])
for i,snapshot in enumerate(redshift):
    comov_dist[i] = cosmo.comoving_distance(redshift[snapshot][0]).value
    redshift_array[i] = redshift[snapshot][0]

comov_dist_mid = np.pad((comov_dist[1:]+comov_dist[0:-1])/2,(1,1))
comov_dist_mid[-1] = comov_dist[-1]

#BUFFER REGION
buffer_comovD = 1/h   ## approx 1/h Mpc assuming haloes don't go farther than this between snapshots, obtained from the rough estimate in Section 1

print (redshift)
# Out:
# {'144': [0.0, 0.0], '143': [0.009522, 41.826713470251796], '142': [0.019134, 83.86264064982566], '141': [0.028838, 126.11015663129425], '140': [0.038634, 168.56277531881085], '139': [0.048524, 211.2225640148051], '138': [0.05, 217.57187177503067], '137': [0.058507, 254.07852770994853], '136': [0.068586, 297.13675281026264], '135': [0.078761, 340.3903067486082], '134': [0.089032, 383.83221308728224], '133': [0.099402, 427.46804683875337], '132': [0.1, 429.9774611816535], '131': [0.10987, 471.2863833627282], '130': [0.120438, 515.2883097052181], '129': [0.131106, 559.4664431546292], '128': [0.141876, 603.8215876501212], '127': [0.152749, 648.3502557249908], '126': [0.163725, 693.0447856293879], '125': [0.174805, 737.901535751655], '124': [0.185992, 782.9247828205471], '123': [0.197284, 828.0985638850425], '122': [0.2, 838.923152327746], '121': [0.208684, 873.4269254679826], '120': [0.220193, 918.9057419024422], '119': [0.237662, 987.3926645608075], '118': [0.261343, 1079.1880596566828], '117': [0.285478, 1171.
lookback_time = np.zeros([len(redshift)])
for i,snapshot in enumerate(redshift):
    lookback_time[i] = cosmo.lookback_time(redshift[snapshot][0]).value
delta_t = lookback_time[1:]-lookback_time[:-1]
oneGigaYear_to_sec = 3.15e16  ## seconds
km_to_Mpc = 3.24078e-20 
rough_estimate_of_how_much_haloes_move_in_Mpc = (delta_t)*oneGigaYear_to_sec*350*km_to_Mpc  ### 300 km/s approximate the average velocity dispersion of the local universe
print (delta_t,rough_estimate_of_how_much_haloes_move_in_Mpc.max())
# Out:
# [0.13577556 0.13516768 0.13456678 0.13394471 0.13332884 0.01973642
#  0.11294225 0.13204758 0.13139547 0.13072298 0.13006808 0.00744258
#  0.12193756 0.12869682 0.1279935  0.12729432 0.12658698 0.12586009
#  0.12512555 0.12440543 0.12364407 0.02945426 0.09344278 0.12214196
#  0.18176887 0.23962473 0.23646635 0.13863514 0.09460423 0.22997454
#  0.22666349 0.2232998  0.21991139 0.21647508 0.21301775 0.20951853
#  0.02966121 0.17635614 0.20247979 0.19893057 0.19537189 0.19180617
#  0.18823016 0.1382274  0.04643705 0.18109389 0.17753802 0.17398823
#  0.17045735 0.16693775 0.1634505  0.15997455 0.15653849 0.0495884
#  0.10353404 0.14974853 0.14640223 0.14309652 0.13982873 0.13660336
#  0.13342422 0.13028565 0.12719455 0.18509884 0.17841686 0.01105559
#  0.16084701 0.16556281 0.1593961  0.15340505 0.14759462 0.14195772
#  0.06567629 0.07082629 0.13121811 0.12611051 0.12117293 0.11640413
#  0.10064528 0.0111568  0.10736303 0.10308213 0.09895646 0.09498184
#  0.05471159 0.03644475 0.08747363 0.08392928 0.08052146 0.07724341
#  0.07409297 0.07106483 0.06815542 0.06536063 0.06267635 0.06009859
#  0.05762413 0.05524795 0.05296831 0.05077971 0.04868008 0.04666568
#  0.05922773 0.05597673 0.05290166 0.04999333 0.04724291 0.04464239
#  0.04218353 0.03985904 0.03766158 0.0355846  0.03362126 0.03176571
#  0.03001217 0.0283547  0.02678868 0.02530863 0.02391006 0.02258866
#  0.0213399  0.02016006 0.01904529 0.01799205 0.01699684 0.01605655
#  0.01516823 0.01432893 0.01353597 0.01278689 0.01207907 0.01141038
#  0.01077872 0.01018189 0.00961808 0.00908548 0.00858226 0.00810687
#  0.00765779 0.00723348 0.00683273 0.00645412 0.00609639 0.00575845] 0.08561695496679614

# %% [markdown]
# ## Section 3: Generating points inside the 4 boxes, compute coordinates and angles

# %%
def generate_grid_points_in_volume(xmin, xmax, ymin, ymax, zmin, zmax):
    x = np.linspace(xmin, xmax,400)
    y = np.linspace(ymin, ymax,400)
    z = np.linspace(zmin, zmax,400)
    xx,yy,zz = np.meshgrid(x,y,z)
    flattened_grid = np.column_stack([xx.flatten(), yy.flatten(),zz.flatten()])
    return flattened_grid.T

# %%
points1 = generate_grid_points_in_volume(0, BoxLength, 0, BoxLength, 0, BoxLength)+0.1
points2 = generate_grid_points_in_volume(0, - BoxLength, 0, BoxLength, 0, BoxLength)+0.1
points3 = generate_grid_points_in_volume(0, BoxLength, 0, - BoxLength, 0, BoxLength)+0.1
points4 = generate_grid_points_in_volume(0, BoxLength, 0, BoxLength, 0, - BoxLength)+0.1

# %%
points_r1 = np.sqrt((points1[0]-origin[0])**2+(points1[1]-origin[1])**2+(points1[2]-origin[2])**2) 
points_r2 = np.sqrt((points2[0]-origin[0])**2+(points2[1]-origin[1])**2+(points2[2]-origin[2])**2) 
points_r3 = np.sqrt((points3[0]-origin[0])**2+(points3[1]-origin[1])**2+(points3[2]-origin[2])**2) 
points_r4 = np.sqrt((points4[0]-origin[0])**2+(points4[1]-origin[1])**2+(points4[2]-origin[2])**2)

# %%
### loop over redshifts and ask at each redshift, the gridpoints falling between the two comoving distances, and within theta from the direction vector
if not FullSky:
    cosangle1 = np.dot(points1.T,direction_vector)/points_r1
    cosangle2 = np.dot(points2.T,direction_vector)/points_r2
    cosangle3 = np.dot(points3.T,direction_vector)/points_r3
    cosangle4 = np.dot(points4.T,direction_vector)/points_r4

# %% [markdown]
# ## Section4: Dataframe with info regarding comoving distance,boxes replicated,etc

# %%
columns = ['comovD_Min(Mpchinv)', 'comovD_Max(Mpchinv)','theta(radians)','buffer_comovD(Mpchinv)','buffer_theta(radians)','direction_vector_x','direction_vector_y','direction_vector_z','Kind_of_join', 'halodir1','halodir2','field1','field2','Box1(w/ buffer)','Box2(w/ buffer)','Box3(w/ buffer)','Box4(w/ buffer)']
df = pd.DataFrame(0,columns=columns,index=np.arange(46*2))

# %%
## compute theta_max given a square_coverage_area
A = 50  ## A is the area coverage in square degrees
cos_theta_max =  1-(A/2)*np.pi/180**2 ## theta is the angle made with the cone
theta = np.arccos(cos_theta_max)## in radians
print (theta)   ## in radians
# Out:
# 0.06964263622787888

# %%
df['Kind_of_join'] = 'left'
df['theta(radians)'] = theta
df['buffer_comovD(Mpchinv)'] = buffer_comovD
df['direction_vector_x'] = 0.844145
df['direction_vector_y'] =0.507213
df['direction_vector_z'] = 0.173648
for i in range(46):
    df.at[2*i,'comovD_Min(Mpchinv)'] = comov_dist[i]
    df.at[2*i,'comovD_Max(Mpchinv)'] = comov_dist_mid[i+1]
    df.at[2*i,'halodir1'] = 50-i
    df.at[2*i,'halodir2'] = 50-i-1
    df.at[2*i,'field1'] = 'last_mainleaf_depthfirst_id'
    df.at[2*i,'field2'] = 'last_mainleaf_depthfirst_id'
    buffer_theta = 1/(comov_dist_mid[i]+5)
    df.at[2*i,'buffer_theta(radians)'] = buffer_theta
    df.at[2*i,'Box1(w/ buffer)'] = ( ((cosangle1>np.cos(theta+buffer_theta))&(points_r1>comov_dist[i]-buffer_comovD)&(points_r1<comov_dist_mid[i+1]+buffer_comovD)).any())
    df.at[2*i,'Box2(w/ buffer)'] = ( ((cosangle2>np.cos(theta+buffer_theta))&(points_r2>comov_dist[i]-buffer_comovD)&(points_r2<comov_dist_mid[i+1]+buffer_comovD)).any())
    df.at[2*i,'Box3(w/ buffer)'] = ( ((cosangle3>np.cos(theta+buffer_theta))&(points_r3>comov_dist[i]-buffer_comovD)&(points_r3<comov_dist_mid[i+1]+buffer_comovD)).any())
    df.at[2*i,'Box4(w/ buffer)'] = ( ((cosangle4>np.cos(theta+buffer_theta))&(points_r4>comov_dist[i]-buffer_comovD)&(points_r4<comov_dist_mid[i+1]+buffer_comovD)).any())
    
    df.at[2*i + 1, 'comovD_Min(Mpchinv)'] = comov_dist_mid[i+1]
    df.at[2*i + 1, 'comovD_Max(Mpchinv)'] = comov_dist[i+1]
    df.at[2*i + 1, 'halodir1'] = 50-i-1
    df.at[2*i + 1, 'halodir2'] =50-i
    df.at[2*i + 1, 'field1'] = 'desc_id'
    df.at[2*i + 1, 'field2'] = 'id'
    buffer_theta = 1/(comov_dist_mid[i+1]+5)
    df.at[2*i + 1,'buffer_theta(radians)'] = buffer_theta
    df.at[2*i + 1, 'Box1(w/ buffer)'] = ( ((cosangle1>np.cos(theta+buffer_theta))&(points_r1>comov_dist_mid[i+1]-buffer_comovD)&(points_r1<comov_dist[i+1]+buffer_comovD)).any())
    df.at[2*i + 1, 'Box2(w/ buffer)'] = ( ((cosangle2>np.cos(theta+buffer_theta))&(points_r2>comov_dist_mid[i+1]-buffer_comovD)&(points_r2<comov_dist[i+1]+buffer_comovD)).any())
    df.at[2*i + 1, 'Box3(w/ buffer)'] = ( ((cosangle3>np.cos(theta+buffer_theta))&(points_r3>comov_dist_mid[i+1]-buffer_comovD)&(points_r3<comov_dist[i+1]+buffer_comovD)).any())
    df.at[2*i + 1, 'Box4(w/ buffer)'] = ( ((cosangle4>np.cos(theta+buffer_theta))&(points_r4>comov_dist_mid[i+1]-buffer_comovD)&(points_r4<comov_dist[i+1]+buffer_comovD)).any())

# %%
df.to_pickle('join_table.pkl')

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df
# Out:
#     comovD_Min(Mpchinv)  comovD_Max(Mpchinv)  theta(radians)  \
# 0              0.000000            32.808360        0.069643
# 1             32.808360            65.616720        0.069643
# 2             65.616720            99.552373        0.069643
# 3             99.552373           133.488025        0.069643
# 4            133.488025           203.093873        0.069643
# 5            203.093873           272.699720        0.069643
# 6            272.699720           339.238616        0.069643
# 7            339.238616           405.777512        0.069643
# 8            405.777512           474.786357        0.069643
# 9            474.786357           543.795202        0.069643
# 10           543.795202           624.173273        0.069643
# 11           624.173273           704.551344        0.069643
# 12           704.551344           769.507176        0.069643
# 13           769.507176           834.463008        0.069643
# 14           834.463008           909.996335        0.069643
# 15           909.996335           985.529661        0.069643
# 16           985.529661          1070.370904        0.069643
# 17          1070.370904          1155.212146        0.069643
# 18          1155.212146          1225.179546        0.069643
# 19          1225.179546          1295.146946        0.069643
# 20          1295.146946          1373.651903        0.069643
# 21          1373.651903          1452.156860        0.069643
# 22          1452.156860          1527.407777        0.069643
# 23          1527.407777          1602.658694        0.069643
# 24          1602.658694          1674.781265        0.069643
# 25          1674.781265          1746.903836        0.069643
# 26          1746.903836          1825.668939        0.069643
# 76            0.507213            0.173648         left        12        11
# 77            0.507213            0.173648         left        11        12
# 78            0.507213            0.173648         left        11        10
# 79            0.507213            0.173648         left        10        11
# 80            0.507213            0.173648         left        10         9
# 81            0.507213            0.173648         left         9        10
# 82            0.507213            0.173648         left         9         8
# 83            0.507213            0.173648         left         8         9
# 84            0.507213            0.173648         left         8         7
# 85            0.507213            0.173648         left         7         8
# 86            0.507213            0.173648         left         7         6
# 87            0.507213            0.173648         left         6         7
# 88            0.507213            0.173648         left         6         5
# 89            0.507213            0.173648         left         5         6
# 90            0.507213            0.173648         left         5         4
# 91            0.507213            0.173648         left         4         5
#
#                          field1                       field2 Box1(w/ buffer)  \
# 0   last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 1                       desc_id                           id            True
# 2   last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 3                       desc_id                           id            True
# 4   last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 5                       desc_id                           id            True
# 6   last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 7                       desc_id                           id            True
# 8   last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 9                       desc_id                           id            True
# 10  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 11                      desc_id                           id            True
# 12  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 13                      desc_id                           id            True
# 14  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 15                      desc_id                           id            True
# 16  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 17                      desc_id                           id            True
# 18  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 19                      desc_id                           id            True
# 20  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 21                      desc_id                           id            True
# 22  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 23                      desc_id                           id            True
# 24  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 25                      desc_id                           id            True
# 26  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 27                      desc_id                           id            True
# 28  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 29                      desc_id                           id            True
# 30  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 31                      desc_id                           id            True
# 32  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 33                      desc_id                           id            True
# 34  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id            True
# 35                      desc_id                           id            True
# 36  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 37                      desc_id                           id           False
# 38  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 39                      desc_id                           id           False
# 40  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 41                      desc_id                           id           False
# 42  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 43                      desc_id                           id           False
# 44  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 45                      desc_id                           id           False
# 46  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 47                      desc_id                           id           False
# 48  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 49                      desc_id                           id           False
# 50  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 51                      desc_id                           id           False
# 52  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 53                      desc_id                           id           False
# 54  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 55                      desc_id                           id           False
# 56  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 57                      desc_id                           id           False
# 58  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 59                      desc_id                           id           False
# 60  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 61                      desc_id                           id           False
# 62  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 63                      desc_id                           id           False
# 64  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 65                      desc_id                           id           False
# 66  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 67                      desc_id                           id           False
# 68  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 69                      desc_id                           id           False
# 70  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 71                      desc_id                           id           False
# 72  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 73                      desc_id                           id           False
# 74  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 75                      desc_id                           id           False
# 76  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 77                      desc_id                           id           False
# 78  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 79                      desc_id                           id           False
# 80  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 81                      desc_id                           id           False
# 82  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 83                      desc_id                           id           False
# 84  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 85                      desc_id                           id           False
# 86  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 87                      desc_id                           id           False
# 88  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 89                      desc_id                           id           False
# 90  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id           False
# 91                      desc_id                           id           False
#
#    Box2(w/ buffer) Box3(w/ buffer) Box4(w/ buffer)
# 0            False           False           False
# 1            False           False           False
# 2            False           False           False
# 3            False           False           False
# 4            False           False           False
# 5            False           False           False
# 6            False           False           False
# 7            False           False           False
# 8            False           False           False
# 9            False           False           False
# 10           False           False           False
# 11           False           False           False
# 12           False           False           False
# 13           False           False           False
# 14           False           False           False
# 15           False           False           False
# 16           False           False           False
# 17           False           False           False
# 18           False           False           False
# 19           False           False           False
# 20           False           False           False
# 21           False           False           False
# 22           False           False           False
# 23           False           False           False
# 24           False           False           False
# 25           False           False           False
# 26           False           False           False
# 27           False           False           False
# 28           False           False           False
# 29           False           False           False
# 30           False           False           False
# 31           False           False           False
# 32            True           False           False
# 33            True           False           False
# 34            True           False           False
# 35            True           False           False
# 36            True           False           False
# 37            True           False           False
# 38            True           False           False
# 39            True           False           False
# 40            True           False           False
# 41            True           False           False
# 42            True           False           False
# 43            True           False           False
# 44            True           False           False
# 45            True           False           False
# 46            True           False           False
# 47            True           False           False
# 48            True           False           False
# 49            True           False           False
# 50            True            True           False
# 51            True            True           False
# 52            True            True           False
# 53            True            True           False
# 54            True            True           False
# 55            True            True           False
# 56            True            True           False
# 57            True            True           False
# 58            True            True           False
# 59            True            True           False
# 60            True            True           False
# 61            True            True           False
# 62            True            True           False
# 63            True            True           False
# 64            True            True           False
# 65            True            True           False
# 66           False            True            True
# 67           False            True            True
# 68           False            True            True
# 69           False            True            True
# 70           False            True            True
# 71           False            True            True
# 72           False            True            True
# 73           False           False            True
# 74           False           False            True
# 75           False           False            True
# 76           False           False            True
# 77           False           False            True
# 78           False           False            True
# 79           False           False            True
# 80           False           False            True
# 81           False           False            True
# 82           False           False            True
# 83           False           False            True
# 84           False           False            True
# 85           False           False            True
# 86           False           False            True
# 87           False           False            True
# 88           False           False            True
# 89           False           False            True
# 90           False           False            True
# 91           False           False            True

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df
# Out:
#     comovD_Min(Mpchinv)  comovD_Max(Mpchinv)  theta(radians)  \
# 0              0.000000            32.808360        0.069643
# 1             32.808360            65.616720        0.069643
# 2             65.616720            99.552373        0.069643
# 3             99.552373           133.488025        0.069643
# 4            133.488025           203.093873        0.069643
# 5            203.093873           272.699720        0.069643
# 6            272.699720           339.238616        0.069643
# 7            339.238616           405.777512        0.069643
# 8            405.777512           474.786357        0.069643
# 9            474.786357           543.795202        0.069643
# 10           543.795202           624.173273        0.069643
# 11           624.173273           704.551344        0.069643
# 12           704.551344           769.507176        0.069643
# 13           769.507176           834.463008        0.069643
# 14           834.463008           909.996335        0.069643
# 15           909.996335           985.529661        0.069643
# 16           985.529661          1070.370904        0.069643
# 17          1070.370904          1155.212146        0.069643
# 18          1155.212146          1225.179546        0.069643
# 19          1225.179546          1295.146946        0.069643
# 20          1295.146946          1373.651903        0.069643
# 21          1373.651903          1452.156860        0.069643
# 22          1452.156860          1527.407777        0.069643
# 23          1527.407777          1602.658694        0.069643
# 24          1602.658694          1674.781265        0.069643
# 25          1674.781265          1746.903836        0.069643
# 26          1746.903836          1825.668939        0.069643
# 27          1825.668939          1904.434042        0.069643
# 28          1904.434042          1979.488535        0.069643
# 29          1979.488535          2054.543028        0.069643
# 30          2054.543028          2126.089801        0.069643
# 31          2126.089801          2197.636573        0.069643
# 32          2197.636573          2274.182071        0.069643
# 33          2274.182071          2350.727569        0.069643
# 34          2350.727569          2423.360650        0.069643
# 35          2423.360650          2495.993732        0.069643
# 18                       1               0.000816         left        41
# 19                       1               0.000772         left        40
# 20                       1               0.000728         left        40
# 21                       1               0.000689         left        39
# 22                       1               0.000655         left        39
# 23                       1               0.000624         left        38
# 24                       1               0.000597         left        38
# 25                       1               0.000572         left        37
# 26                       1               0.000548         left        37
# 27                       1               0.000525         left        36
# 28                       1               0.000505         left        36
# 29                       1               0.000487         left        35
# 30                       1               0.000470         left        35
# 31                       1               0.000455         left        34
# 32                       1               0.000440         left        34
# 33                       1               0.000425         left        33
# 34                       1               0.000413         left        33
# 35                       1               0.000401         left        32
# 36                       1               0.000389         left        32
# 37                       1               0.000378         left        31
# 38                       1               0.000367         left        31
# 39                       1               0.000358         left        30
# 40                       1               0.000349         left        30
# 41                       1               0.000340         left        29
# 42                       1               0.000332         left        29
# 43                       1               0.000324         left        28
# 44                       1               0.000317         left        28
# 45                       1               0.000311         left        27
# 46                       1               0.000304         left        27
# 47                       1               0.000298         left        26
# 48                       1               0.000292         left        26
# 49                       1               0.000286         left        25
# 50                       1               0.000281         left        25
# 51                       1               0.000276         left        24
# 52                       1               0.000271         left        24
# 53                       1               0.000266         left        23
# 54                       1               0.000262         left        23
# 55                       1               0.000258         left        22
# 56                       1               0.000253         left        22
# 57                       1               0.000249         left        21
# 58                       1               0.000246         left        21
# 59                       1               0.000242         left        20
# 60                       1               0.000238         left        20
# 61                       1               0.000235         left        19
# 62                       1               0.000232         left        19
# 63                       1               0.000228         left        18
# 64                       1               0.000225         left        18
# 65                       1               0.000222         left        17
# 66                       1               0.000220         left        17
# 67                       1               0.000217         left        16
# 68                       1               0.000213         left        16
# 69                       1               0.000209         left        15
# 70                       1               0.000206         left        15
# 71                       1               0.000202         left        14
# 72                       1               0.000199         left        14
# 73                       1               0.000196         left        13
# 74                       1               0.000193         left        13
# 75                       1               0.000191         left        12
# 76                       1               0.000187         left        12
# 77                       1               0.000184         left        11
# 78                       1               0.000180         left        11
# 79                       1               0.000177         left        10
# 80                       1               0.000175         left        10
# 81                       1               0.000172         left         9
# 82                       1               0.000170         left         9
# 83                       1               0.000167         left         8
# 84                       1               0.000165         left         8
# 85                       1               0.000163         left         7
# 86                       1               0.000161         left         7
# 87                       1               0.000159         left         6
# 88                       1               0.000157         left         6
# 89                       1               0.000155         left         5
# 90                       1               0.000153         left         5
# 91                       1               0.000151         left         4
#
#     halodir2                       field1                       field2  \
# 0         49  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 1         50                      desc_id                           id
# 2         48  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 3         49                      desc_id                           id
# 4         47  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 5         48                      desc_id                           id
# 6         46  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 7         47                      desc_id                           id
# 8         45  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 9         46                      desc_id                           id
# 10        44  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 11        45                      desc_id                           id
# 12        43  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 13        44                      desc_id                           id
# 14        42  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 15        43                      desc_id                           id
# 16        41  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 17        42                      desc_id                           id
# 18        40  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 19        41                      desc_id                           id
# 20        39  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 21        40                      desc_id                           id
# 22        38  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 23        39                      desc_id                           id
# 24        37  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 25        38                      desc_id                           id
# 26        36  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 27        37                      desc_id                           id
# 28        35  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 29        36                      desc_id                           id
# 30        34  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 31        35                      desc_id                           id
# 32        33  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 33        34                      desc_id                           id
# 34        32  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 35        33                      desc_id                           id
# 36        31  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 37        32                      desc_id                           id
# 38        30  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 39        31                      desc_id                           id
# 40        29  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 41        30                      desc_id                           id
# 42        28  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 43        29                      desc_id                           id
# 44        27  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 45        28                      desc_id                           id
# 46        26  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 47        27                      desc_id                           id
# 48        25  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 49        26                      desc_id                           id
# 50        24  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 51        25                      desc_id                           id
# 52        23  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 53        24                      desc_id                           id
# 54        22  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 55        23                      desc_id                           id
# 56        21  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 57        22                      desc_id                           id
# 58        20  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 59        21                      desc_id                           id
# 60        19  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 61        20                      desc_id                           id
# 62        18  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 63        19                      desc_id                           id
# 64        17  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 65        18                      desc_id                           id
# 66        16  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 67        17                      desc_id                           id
# 68        15  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 69        16                      desc_id                           id
# 70        14  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 71        15                      desc_id                           id
# 72        13  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 73        14                      desc_id                           id
# 74        12  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 75        13                      desc_id                           id
# 76        11  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 77        12                      desc_id                           id
# 78        10  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 79        11                      desc_id                           id
# 80         9  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 81        10                      desc_id                           id
# 82         8  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 83         9                      desc_id                           id
# 84         7  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 85         8                      desc_id                           id
# 86         6  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 87         7                      desc_id                           id
# 88         5  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 89         6                      desc_id                           id
# 90         4  last_mainleaf_depthfirst_id  last_mainleaf_depthfirst_id
# 91         5                      desc_id                           id
#
#    Box1(0,0,0)(w/ buffer) Box2(L,0,0)(w/ buffer) Box3(L,L,0)(w/ buffer)  \
# 0                    True                  False                  False
# 1                    True                  False                  False
# 2                    True                  False                  False
# 3                    True                  False                  False
# 4                    True                  False                  False
# 5                    True                  False                  False
# 6                    True                  False                  False
# 7                    True                  False                  False
# 8                    True                  False                  False
# 9                    True                  False                  False
# 10                   True                  False                  False
# 11                   True                  False                  False
# 12                   True                  False                  False
# 13                   True                  False                  False
# 14                   True                  False                  False
# 15                   True                  False                  False
# 16                   True                  False                  False
# 17                   True                  False                  False
# 18                   True                  False                  False
# 19                   True                  False                  False
# 20                   True                  False                  False
# 21                   True                  False                  False
# 22                   True                  False                  False
# 23                   True                  False                  False
# 24                   True                  False                  False
# 25                   True                  False                  False
# 26                   True                  False                  False
# 27                   True                  False                  False
# 28                   True                  False                  False
# 29                   True                  False                  False
# 30                   True                  False                  False
# 31                   True                  False                  False
# 32                   True                   True                  False
# 33                   True                   True                  False
# 34                   True                   True                  False
# 35                   True                   True                  False
# 36                  False                   True                  False
# 37                  False                   True                  False
# 38                  False                   True                  False
# 39                  False                   True                  False
# 40                  False                   True                  False
# 41                  False                   True                  False
# 42                  False                   True                  False
# 43                  False                   True                  False
# 44                  False                   True                  False
# 45                  False                   True                  False
# 46                  False                   True                  False
# 47                  False                   True                  False
# 48                  False                   True                  False
# 49                  False                   True                  False
# 50                  False                   True                   True
# 51                  False                   True                   True
# 52                  False                   True                   True
# 53                  False                   True                   True
# 54                  False                   True                   True
# 55                  False                   True                   True
# 56                  False                   True                   True
# 57                  False                   True                   True
# 58                  False                   True                   True
# 59                  False                   True                   True
# 60                  False                   True                   True
# 61                  False                   True                   True
# 62                  False                   True                   True
# 63                  False                   True                   True
# 64                  False                   True                   True
# 65                  False                   True                   True
# 66                  False                  False                   True
# 67                  False                  False                   True
# 68                  False                  False                   True
# 69                  False                  False                   True
# 70                  False                  False                   True
# 71                  False                  False                   True
# 72                  False                  False                   True
# 73                  False                  False                  False
# 74                  False                  False                  False
# 75                  False                  False                  False
# 76                  False                  False                  False
# 77                  False                  False                  False
# 78                  False                  False                  False
# 79                  False                  False                  False
# 80                  False                  False                  False
# 81                  False                  False                  False
# 82                  False                  False                  False
# 83                  False                  False                  False
# 84                  False                  False                  False
# 85                  False                  False                  False
# 86                  False                  False                  False
# 87                  False                  False                  False
# 88                  False                  False                  False
# 89                  False                  False                  False
# 90                  False                  False                  False
# 91                  False                  False                  False
#
#    Box4(2L,L,0)(w/ buffer)
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# 5                    False
# 6                    False
# 7                    False
# 8                    False
# 9                    False
# 10                   False
# 11                   False
# 12                   False
# 13                   False
# 14                   False
# 15                   False
# 16                   False
# 17                   False
# 18                   False
# 19                   False
# 20                   False
# 21                   False
# 22                   False
# 23                   False
# 24                   False
# 25                   False
# 26                   False
# 27                   False
# 28                   False
# 29                   False
# 30                   False
# 31                   False
# 32                   False
# 33                   False
# 34                   False
# 35                   False
# 36                   False
# 37                   False
# 38                   False
# 39                   False
# 40                   False
# 41                   False
# 42                   False
# 43                   False
# 44                   False
# 45                   False
# 46                   False
# 47                   False
# 48                   False
# 49                   False
# 50                   False
# 51                   False
# 52                   False
# 53                   False
# 54                   False
# 55                   False
# 56                   False
# 57                   False
# 58                   False
# 59                   False
# 60                   False
# 61                   False
# 62                   False
# 63                   False
# 64                   False
# 65                   False
# 66                    True
# 67                    True
# 68                    True
# 69                    True
# 70                    True
# 71                    True
# 72                    True
# 73                    True
# 74                    True
# 75                    True
# 76                    True
# 77                    True
# 78                    True
# 79                    True
# 80                    True
# 81                    True
# 82                    True
# 83                    True
# 84                    True
# 85                    True
# 86                    True
# 87                    True
# 88                    True
# 89                    True
# 90                    True
# 91                    True

# %% [markdown]
# ## Section5: (Optional) Table for downloading data from Original Catalog (FullSky)

# %%
columns = ['comovD_Min(Mpc)', 'comovD_Max(Mpc)','buffer_comovD(Mpc)','halodir','Box1(0,0,0)(w/ buffer)','Box2(-L,0,0)(w/ buffer)','Box3(0,-L,0)(w/ buffer)','Box4(0,0,-L)(w/ buffer)']
df = pd.DataFrame(0,columns=columns,index=np.arange(len(redshift)),dtype=np.float64)
df['Box1(0,0,0)(w/ buffer)'] = df['Box1(0,0,0)(w/ buffer)'].astype(bool)
df['Box2(-L,0,0)(w/ buffer)'] = df['Box2(-L,0,0)(w/ buffer)'].astype(bool)
df['Box3(0,-L,0)(w/ buffer)'] = df['Box3(0,-L,0)(w/ buffer)'].astype(bool)
df['Box4(0,0,-L)(w/ buffer)'] = df['Box4(0,0,-L)(w/ buffer)'].astype(bool)
df['halodir']=df['halodir'].astype('string')

# %%
comov_dist_padded = np.pad(comov_dist,(1,1))
comov_dist_padded[-1] =comov_dist_padded[-2]

# %%
df['buffer_comovD(Mpc)'] = buffer_comovD
df['origin_x'] = BoxLength/4
df['origin_y'] = BoxLength/4
df['origin_z'] = BoxLength/4
df['BoxSize'] = BoxLength

for i,snap in enumerate(redshift):
    df.at[i,'comovD_Min(Mpc)'] = comov_dist_padded[i]
    df.at[i,'comovD_Max(Mpc)'] = comov_dist_padded[i+2]
    df.at[i,'halodir'] = snap
    df.at[i,'Box1(0,0,0)(w/ buffer)'] = ((points_r1>comov_dist_padded[i]-buffer_comovD)&(points_r1<comov_dist_padded[i+2]+buffer_comovD)).any()
    df.at[i,'Box2(-L,0,0)(w/ buffer)'] = ((points_r2>comov_dist_padded[i]-buffer_comovD)&(points_r2<comov_dist_padded[i+2]+buffer_comovD)).any()
    df.at[i,'Box3(0,-L,0)(w/ buffer)'] = ((points_r3>comov_dist_padded[i]-buffer_comovD)&(points_r3<comov_dist_padded[i+2]+buffer_comovD)).any()
    df.at[i,'Box4(0,0,-L)(w/ buffer)'] = ((points_r4>comov_dist_padded[i]-buffer_comovD)&(points_r4<comov_dist_padded[i+2]+buffer_comovD)).any()

# %%
df
# Out:
#      comovD_Min(Mpc)  comovD_Max(Mpc)  buffer_comovD(Mpc) halodir  \
# 0           0.000000        41.826713            1.468429     144
# 1           0.000000        83.862641            1.468429     143
# 2          41.826713       126.110157            1.468429     142
# 3          83.862641       168.562775            1.468429     141
# 4         126.110157       211.222564            1.468429     140
# ..               ...              ...                 ...     ...
# 140     11318.144640     11434.217026            1.468429       4
# 141     11376.734779     11490.611873            1.468429       3
# 142     11434.217026     11545.938932            1.468429       2
# 143     11490.611873     11600.218108            1.468429       1
# 144     11545.938932     11600.218108            1.468429       0
#
#      Box1(0,0,0)(w/ buffer)  Box2(-L,0,0)(w/ buffer)  Box3(0,-L,0)(w/ buffer)  \
# 0                      True                    False                    False
# 1                      True                    False                    False
# 2                      True                    False                    False
# 3                      True                    False                    False
# 4                      True                    False                    False
# ..                      ...                      ...                      ...
# 140                   False                    False                    False
# 141                   False                    False                    False
# 142                   False                    False                    False
# 143                   False                    False                    False
# 144                   False                    False                    False
#
#      Box4(0,0,-L)(w/ buffer)  origin_x  origin_y  origin_z  BoxSize
# 0                      False     700.0     700.0     700.0   2800.0
# 1                      False     700.0     700.0     700.0   2800.0
# 2                      False     700.0     700.0     700.0   2800.0
# 3                      False     700.0     700.0     700.0   2800.0
# 4                      False     700.0     700.0     700.0   2800.0
# ..                       ...       ...       ...       ...      ...
# 140                    False     700.0     700.0     700.0   2800.0
# 141                    False     700.0     700.0     700.0   2800.0
# 142                    False     700.0     700.0     700.0   2800.0
# 143                    False     700.0     700.0     700.0   2800.0
# 144                    False     700.0     700.0     700.0   2800.0
#
# [145 rows x 12 columns]

# %%
df
# Out:
#      comovD_Min(Mpc)  comovD_Max(Mpc)  buffer_comovD(Mpc) halodir  \
# 0           0.000000        41.826713            1.468429     144
# 1           0.000000        83.862641            1.468429     143
# 2          41.826713       126.110157            1.468429     142
# 3          83.862641       168.562775            1.468429     141
# 4         126.110157       211.222564            1.468429     140
# ..               ...              ...                 ...     ...
# 140     11318.144640     11434.217026            1.468429       4
# 141     11376.734779     11490.611873            1.468429       3
# 142     11434.217026     11545.938932            1.468429       2
# 143     11490.611873     11600.218108            1.468429       1
# 144     11545.938932     11600.218108            1.468429       0
#
#      Box1(0,0,0)(w/ buffer)  Box2(-L,0,0)(w/ buffer)  Box3(0,-L,0)(w/ buffer)  \
# 0                      True                    False                    False
# 1                      True                    False                    False
# 2                      True                    False                    False
# 3                      True                    False                    False
# 4                      True                    False                    False
# ..                      ...                      ...                      ...
# 140                   False                    False                    False
# 141                   False                    False                    False
# 142                   False                    False                    False
# 143                   False                    False                    False
# 144                   False                    False                    False
#
#      Box4(0,0,-L)(w/ buffer)  origin_x  origin_y  origin_z  BoxSize
# 0                      False     700.0     700.0     700.0   2800.0
# 1                      False     700.0     700.0     700.0   2800.0
# 2                      False     700.0     700.0     700.0   2800.0
# 3                      False     700.0     700.0     700.0   2800.0
# 4                      False     700.0     700.0     700.0   2800.0
# ..                       ...       ...       ...       ...      ...
# 140                    False     700.0     700.0     700.0   2800.0
# 141                    False     700.0     700.0     700.0   2800.0
# 142                    False     700.0     700.0     700.0   2800.0
# 143                    False     700.0     700.0     700.0   2800.0
# 144                    False     700.0     700.0     700.0   2800.0
#
# [145 rows x 12 columns]

# %%
df.to_pickle('/nfs/pic.es/user/s/sramakri/jpynb/lc_interpolator_dask_version/dask_region_selector/select_table.pkl')

# %%
string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 string
#
# NameError: name 'string' is not defined

# %%
Memory = np.array([0.002,0.02,0.018,0.056,0.107,0.201,0.297,0.390,0.602,0.797,0.992,1.3,1.5,1.9,2.3,2.6,3,3.5,4,4.5,5,5.5,5.8,6.1,6.9,7.3,7.1,7.5,8,8.3,8.5,8.8,8.6,8.4,11,12.6,12,11,11.63,11.24,8.5,6.4,4.2,2.6,1.5,0.699,0.147])

# %%
Memory.shape
# Out:
# (47,)

# %%
import matplotlib.pyplot as plt
plt.scatter(redshift_array,Memory)
plt.xlabel('redshift')
plt.ylabel('Memory in GB')
# Out:
# Text(0, 0.5, 'Memory in GB')

# %% [markdown]
# ## Estimate of the Size

# %%
path = '/nfs/pic.es/user/s/sramakri/jpynb/'
import sys
sys.path.append(path)
from colossus.cosmology import cosmology
from colossus.lss import mass_function
import CosmologyLibraryM as cm
ns = 0.9667
sig8 = 0.8159
cosmolib = cm.cosmology(Omega_matter=om,Omega_lambda=ol,H_0=100*h,sigma_8=sig8,ns=ns)

k,Tfn = np.loadtxt(path+'camb_96239641_transfer_1.dat',unpack=True,usecols=[0,1])

# %%
df = df.set_index('halodir')

# %%
def Size_LCparts_in_GB(M_min,float_size,no_of_columns,flag=0):
    m = np.logspace(np.log10(M_min),15,30)
    dlnm = (np.log(m[1:])-np.log(m[0:-1])).mean()
    m_mid = np.sqrt(m[1:]*m[:-1])
    tinkermf = np.zeros([len(redshift),len(m_mid)])
    comov_dist = np.zeros([len(redshift)])
    N_halo_const = 4*np.pi/3
    Vol = np.zeros([len(redshift)])
    for i,key in enumerate(redshift.keys()):
        tinkermf[i,:] = (cosmolib.T08(m_mid,k,Tfn,z=redshift[key][0])).flatten()
        Vol[i] = N_halo_const* ((df.loc[key]['comovD_Max(Mpc)']+1.4)**3-(df.loc[key]['comovD_Min(Mpc)']-1.4)**3)*np.sum(tinkermf[i,:]*dlnm)*h**3  
    if flag==0:
        return Vol*float_size*no_of_columns/1e9
    else:
        return Vol

# %%
redshift_file='/nfs/pic.es/user/s/sramakri/Flamingo/flamingo_params.txt'
zdf=pd.read_csv(redshift_file,usecols=[0,2],names=['snap','z'],skiprows=1,delimiter=' ')

# %%
zdf = zdf.set_index('snap')

# %%
zdf['memoryGB'] = 0
zdf['memoryGB'] = zdf['memoryGB'].astype(float)

# %%
zdf.loc[144,'memoryGB'] = 0.0099
zdf.loc[143,'memoryGB'] = 0.058
zdf.loc[142,'memoryGB'] = 0.172
zdf.loc[141,'memoryGB'] = 0.128
zdf.loc[140,'memoryGB'] = 0.583
zdf.loc[139,'memoryGB'] = 0.433
zdf.loc[138,'memoryGB'] = 0.540
zdf.loc[137,'memoryGB'] = 1.2
zdf.loc[136,'memoryGB'] = 1.8
zdf.loc[135,'memoryGB'] = 2.4
zdf.loc[134,'memoryGB'] = 2.9
zdf.loc[133,'memoryGB'] = 1.8
zdf.loc[132,'memoryGB'] = 2.0
zdf.loc[131,'memoryGB'] = 4.2
zdf.loc[130,'memoryGB'] = 5.2
zdf.loc[129,'memoryGB'] = 6.2
zdf.loc[128,'memoryGB'] = 7.1
zdf.loc[127,'memoryGB'] = 8.3
zdf.loc[126,'memoryGB'] = 9.5
zdf.loc[125,'memoryGB'] = 11
zdf.loc[124,'memoryGB'] = 13
zdf.loc[123,'memoryGB'] = 8.2
zdf.loc[122,'memoryGB'] = 7.4
zdf.loc[121,'memoryGB'] = 14
zdf.loc[120,'memoryGB'] = 22
zdf.loc[119,'memoryGB'] = 35
zdf.loc[118,'memoryGB'] = 45
zdf.loc[117,'memoryGB'] = 41
zdf.loc[116,'memoryGB'] = 28
zdf.loc[115,'memoryGB'] = 43
zdf.loc[114,'memoryGB'] = 64

# %%
s = Size_LCparts_in_GB(1.6e10,4,20,1)

# %%
import matplotlib.pyplot as plt
plt.plot(zdf['z'],s[::-1]/3.5e6,marker='.',label='forecast with Tinker2008')
plt.scatter(zdf['z'],zdf['memoryGB'],marker='x',color='red',label='actual filesize')
plt.xlim([0.009,10])
plt.ylim([0.009,1800])
plt.yscale('log')
plt.ylabel('Memory in GB')
plt.xlabel('Redshift')
plt.xscale('log')
plt.legend(loc='lower right')

# %%
df.loc['144']['comovD_Max(Mpc)']
# Out:
# 41.826713470251796

# %%
(om-0.045)*h**2
# Out:
# 0.120397456971

# %%
om
# Out:
# 0.304611

# %%
ol
# Out:
# 0.693922
